# %%
from pybaseball import schedule_and_record
import pandas as pd
import hvplot.pandas
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn import svm

# %%
mariners_data = schedule_and_record(2022, 'SEA')
mariners_data = mariners_data.set_index('Date')
mariners_data['Runs_Scored'] = mariners_data['R'].cumsum()
mariners_data['Runs_Allowed'] = mariners_data['RA'].cumsum()
mariners_data['RD'] = mariners_data['Runs_Scored'] - mariners_data['Runs_Allowed']
mariners_data = mariners_data[['Home_Away', 'W/L','W-L', 'R','RA', 'Rank', 'GB', 'D/N', 'Streak', 'Runs_Scored', 'Runs_Allowed', 'RD']]
mariners_data['W/L'] = mariners_data['W/L'].replace('W-wo', 'W')
mariners_data['W/L'] = mariners_data['W/L'].replace('L-wo', 'L')
mariners_data = mariners_data.drop(columns='GB')
#Replace W with 1 and L with 0
#Replace Home/Away @ with 0, Home with 1
#Replace D (Day) with 0 and N (night) with 1

mariners_data['W/L'] = mariners_data['W/L'].replace('W', '1')
mariners_data['W/L'] = mariners_data['W/L'].replace('L', '0')
mariners_data['Home_Away'] = mariners_data['Home_Away'].replace('@', '0')
mariners_data['Home_Away'] = mariners_data['Home_Away'].replace('Home', '1')
mariners_data['D/N'] = mariners_data['D/N'].replace('D', '0')
mariners_data['D/N'] = mariners_data['D/N'].replace('N', '1')
#Convert to Integer
mariners_data['W/L'] = mariners_data['W/L'].astype(int)
mariners_data['Home_Away'] = mariners_data['Home_Away'].astype(int)
mariners_data['D/N'] = mariners_data['D/N'].astype(int)
mariners_data['Win_Total'] = mariners_data['W/L'].cumsum()

# %%
mariners_data
# Out:
#                     Home_Away  W/L    W-L    R    RA  Rank  D/N  Streak  \
# Date
# Friday, Apr 8               0    1    1-0  2.0   1.0   2.0    0       1
# Saturday, Apr 9             0    1    2-0  4.0   3.0   1.0    0       2
# Sunday, Apr 10              0    0    2-1  4.0  10.0   2.0    0      -1
# Monday, Apr 11              0    0    2-2  0.0   4.0   2.0    1      -2
# Tuesday, Apr 12             0    0    2-3  2.0   3.0   3.0    0      -3
# ...                       ...  ...    ...  ...   ...   ...  ...     ...
# Sunday, Oct 2               1    0  87-71  3.0  10.0   2.0    0      -1
# Monday, Oct 3               1    0  87-72  3.0   4.0   2.0    1      -2
# Tuesday, Oct 4 (1)          1    1  88-72  7.0   6.0   2.0    0       1
# Tuesday, Oct 4 (2)          1    1  89-72  9.0   6.0   2.0    0       2
# Wednesday, Oct 5            1    1  90-72  5.0   4.0   2.0    0       3
#
#                     Runs_Scored  Runs_Allowed    RD  Win_Total
# Date
# ...

# %%
mariners_data_2021 = schedule_and_record(2022, 'SEA')
mariners_data_2021 = mariners_data_2021.set_index('Date')
mariners_data_2021['Runs_Scored'] = mariners_data_2021['R'].cumsum()
mariners_data_2021['Runs_Allowed'] = mariners_data_2021['RA'].cumsum()
mariners_data_2021['RD'] = mariners_data_2021['Runs_Scored'] - mariners_data_2021['Runs_Allowed']
mariners_data_2021 = mariners_data_2021[['Home_Away', 'W/L','W-L', 'R','RA', 'Rank', 'GB', 'D/N', 'Streak', 'Runs_Scored', 'Runs_Allowed', 'RD']]
mariners_data_2021['W/L'] = mariners_data_2021['W/L'].replace('W-wo', 'W')
mariners_data_2021['W/L'] = mariners_data_2021['W/L'].replace('L-wo', 'L')
mariners_data_2021 = mariners_data_2021.drop(columns='GB')
#Replace W with 1 and L with 0
#Replace Home/Away @ with 0, Home with 1
#Replace D (Day) with 0 and N (night) with 1

mariners_data_2021['W/L'] = mariners_data_2021['W/L'].replace('W', '1')
mariners_data_2021['W/L'] = mariners_data_2021['W/L'].replace('L', '0')
mariners_data_2021['Home_Away'] = mariners_data_2021['Home_Away'].replace('@', '0')
mariners_data_2021['Home_Away'] = mariners_data_2021['Home_Away'].replace('Home', '1')
mariners_data_2021['D/N'] = mariners_data_2021['D/N'].replace('D', '0')
mariners_data_2021['D/N'] = mariners_data_2021['D/N'].replace('N', '1')
#Convert to Integer
mariners_data_2021['W/L'] = mariners_data_2021['W/L'].astype(int)
mariners_data_2021['Home_Away'] = mariners_data_2021['Home_Away'].astype(int)
mariners_data_2021['D/N'] = mariners_data_2021['D/N'].astype(int)
mariners_data_2021['Win_Total'] = mariners_data_2021['W/L'].cumsum()
mariners_data_2021
# Out:
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pybaseball/team_results.py:70: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop('',1) #not a useful column
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pybaseball/team_results.py:83: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop('Streak2',1)
#                     Home_Away  W/L    W-L    R    RA  Rank  D/N  Streak  \
# Date
# Friday, Apr 8               0    1    1-0  2.0   1.0   2.0    0       1
# Saturday, Apr 9             0    1    2-0  4.0   3.0   1.0    0       2
# Sunday, Apr 10              0    0    2-1  4.0  10.0   2.0    0      -1
# Monday, Apr 11              0    0    2-2  0.0   4.0   2.0    1      -2
# Tuesday, Apr 12             0    0    2-3  2.0   3.0   3.0    0      -3
# ...

# %%
astros_data = schedule_and_record(2022, 'HOU')
astros_data = astros_data.set_index('Date')
astros_data['Runs_Scored'] = astros_data['R'].cumsum()
astros_data['Runs_Allowed'] = astros_data['RA'].cumsum()
astros_data['RD'] = astros_data['Runs_Scored'] - astros_data['Runs_Allowed']
astros_data = astros_data[['Home_Away', 'W/L','W-L', 'R','RA', 'Rank', 'GB', 'D/N', 'Streak', 'Runs_Scored', 'Runs_Allowed', 'RD']]
astros_data['W/L'] = astros_data['W/L'].replace('W-wo', 'W')
astros_data['W/L'] = astros_data['W/L'].replace('L-wo', 'L')
astros_data = astros_data.drop(columns='GB')
#Replace W with 1 and L with 0
#Replace Home/Away @ with 0, Home with 1
#Replace D (Day) with 0 and N (night) with 1

astros_data['W/L'] = astros_data['W/L'].replace('W', '1')
astros_data['W/L'] = astros_data['W/L'].replace('L', '0')
astros_data['Home_Away'] = astros_data['Home_Away'].replace('@', '0')
astros_data['Home_Away'] = astros_data['Home_Away'].replace('Home', '1')
astros_data['D/N'] = astros_data['D/N'].replace('D', '0')
astros_data['D/N'] = astros_data['D/N'].replace('N', '1')
#Convert to Integer
astros_data['W/L'] = astros_data['W/L'].astype(int)
astros_data['Home_Away'] = astros_data['Home_Away'].astype(int)
astros_data['D/N'] = astros_data['D/N'].astype(int)
astros_data['Win_Total'] = astros_data['W/L'].cumsum()
astros_data
# Out:
#                   Home_Away  W/L     W-L     R   RA  Rank  D/N  Streak  \
# Date
# Thursday, Apr 7           0    1     1-0   3.0  1.0   1.0    1       1
# Friday, Apr 8             0    1     2-0  13.0  6.0   1.0    1       2
# Saturday, Apr 9           0    0     2-1   0.0  2.0   2.0    1      -1
# Sunday, Apr 10            0    1     3-1   4.0  1.0   1.0    0       1
# Tuesday, Apr 12           0    1     4-1   2.0  1.0   1.0    1       2
# ...                     ...  ...     ...   ...  ...   ...  ...     ...
# Saturday, Oct 1           1    1  103-55   2.0  1.0   1.0    1       1
# Sunday, Oct 2             1    1  104-55   3.0  1.0   1.0    0       2
# Monday, Oct 3             1    0  104-56   0.0  3.0   1.0    1      -1
# Tuesday, Oct 4            1    1  105-56  10.0  0.0   1.0    1       1
# Wednesday, Oct 5          1    1  106-56   3.0  2.0   1.0    0       2
#
#                   Runs_Scored  Runs_Allowed     RD  Win_Total
# Date
# ...

# %%
as_data = schedule_and_record(2022, 'OAK')
as_data = as_data.set_index('Date')
as_data['Runs_Scored'] = as_data['R'].cumsum()
as_data['Runs_Allowed'] = as_data['RA'].cumsum()
as_data['RD'] = as_data['Runs_Scored'] - as_data['Runs_Allowed']
as_data = as_data[['Home_Away', 'W/L','W-L', 'R','RA', 'Rank', 'GB', 'D/N', 'Streak', 'Runs_Scored', 'Runs_Allowed', 'RD']]
as_data['W/L'] = as_data['W/L'].replace('W-wo', 'W')
as_data['W/L'] = as_data['W/L'].replace('L-wo', 'L')
as_data = as_data.drop(columns='GB')
#Replace W with 1 and L with 0
#Replace Home/Away @ with 0, Home with 1
#Replace D (Day) with 0 and N (night) with 1

as_data['W/L'] = as_data['W/L'].replace('W', '1')
as_data['W/L'] = as_data['W/L'].replace('L', '0')
as_data['Home_Away'] = as_data['Home_Away'].replace('@', '0')
as_data['Home_Away'] = as_data['Home_Away'].replace('Home', '1')
as_data['D/N'] = as_data['D/N'].replace('D', '0')
as_data['D/N'] = as_data['D/N'].replace('N', '1')
#Convert to Integer
as_data['W/L'] = as_data['W/L'].astype(int)
as_data['Home_Away'] = as_data['Home_Away'].astype(int)
as_data['D/N'] = as_data['D/N'].astype(int)
as_data['Win_Total'] = as_data['W/L'].cumsum()
as_data
# Out:
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pybaseball/team_results.py:70: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop('',1) #not a useful column
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pybaseball/team_results.py:83: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop('Streak2',1)
#                   Home_Away  W/L     W-L     R   RA  Rank  D/N  Streak  \
# Date
# Friday, Apr 8             0    0     0-1   5.0  9.0   3.0    0      -1
# Saturday, Apr 9           0    0     0-2   2.0  4.0   4.0    0      -2
# Sunday, Apr 10            0    1     1-2   4.0  1.0   3.0    0       1
# Monday, Apr 11            0    1     2-2  13.0  2.0   2.0    1       2
# Tuesday, Apr 12           0    0     2-3   8.0  9.0   3.0    1      -1
# ...
